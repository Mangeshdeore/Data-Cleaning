# %% [markdown]
# <a href="https://colab.research.google.com/github/Mangeshdeore/Data-Cleaning/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In This project I have clean the data for analysis and finding insights from it.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Lets load up the data

# %%
df=pd.read_csv('/content/hotel-booking-data.txt', delimiter= '\t')
df
# Out:
#            Date       Company        Person Name  Room number
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0
# 3        Hotels           NaN                NaN          NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0
# ..          ...           ...                ...          ...
# 190   Cleartrip           NaN                NaN          NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0
# 194      Hotels           NaN                NaN          NaN
#
# [195 rows x 4 columns]

# %%
df.describe()
# Out:
#        Room number
# count   153.000000
# mean   3079.326797
# std    1718.791186
# min    1001.000000
# 25%    2001.000000
# 50%    3008.000000
# 75%    4010.000000
# max    7002.000000

# %%
df['Company'].value_counts()
# Out:
# Leexo           3
# Fivechat        3
# Quinu           3
# Jabbersphere    2
# Twitterlist     2
#                ..
# Topiclounge     1
# Shufflebeat     1
# Skyvu           1
# Youspan         1
# Twitterworks    1
# Name: Company, Length: 114, dtype: int64

# %% [markdown]
# Lots of NAN values are present in this dataset. If dataset is large and count of NAN values are very less then we can use this dropna function to remove the NAN values for cleaning the dataset.

# %%
df1= df.dropna()
df1
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]

# %%
df.head()
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0
# 3      Hotels     NaN                NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0

# %%
df['2XRoom']=df['Room number']*2
df
# Out:
#            Date       Company        Person Name  Room number   2XRoom
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
# [195 rows x 5 columns]

# %%
df['Room number'].isna().sum()
# Out:
# 42

# %%
df['Room number'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 190     True
# 191    False
# 192    False
# 193    False
# 194     True
# Name: Room number, Length: 195, dtype: bool

# %%
Duplicate=df['Room number'].isna()

df['Booking']=np.where(Duplicate, df['Date'], np.nan)

# %%
df
# Out:
#            Date       Company        Person Name  Room number   2XRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#        Booking
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Hotels
# 4          NaN
# ..         ...
# ...

# %%
df['Booking'].fillna(method='bfill')
# Out:
# 0         Hotels
# 1         Hotels
# 2         Hotels
# 3         Hotels
# 4        Booking
#          ...
# 190    Cleartrip
# 191       Hotels
# 192       Hotels
# 193       Hotels
# 194       Hotels
# Name: Booking, Length: 195, dtype: object

# %%
df
# Out:
#            Date       Company        Person Name  Room number   2XRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#        Booking
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Hotels
# 4          NaN
# ..         ...
# ...

# %%
df['Booking'].fillna(method='bfill', inplace=True)
df
# Out:
#            Date       Company        Person Name  Room number   2XRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#        Booking
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 3       Hotels
# 4      Booking
# ..         ...
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#            Date       Company          Person Name  Room number   2XRoom  \
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0   8024.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0   2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0   6030.0
# ..          ...           ...                  ...          ...      ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0   2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0  14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0   2020.0
#
#      Booking
# 0     Hotels
# 1     Hotels
# 2     Hotels
# 4    Booking
# 5    Booking
# ...

# %%
df['Booking'].value_counts()
# Out:
# Expedia             48
# Hotels              39
# Booking             24
# Travel Agent 007    12
# Cleartrip           11
# Name: Booking, dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Leexo           3
# Fivechat        3
# Quinu           3
# Jabbersphere    2
# Twitterlist     2
#                ..
# Topiclounge     1
# Shufflebeat     1
# Skyvu           1
# Youspan         1
# Twitterworks    1
# Name: Company, Length: 114, dtype: int64
